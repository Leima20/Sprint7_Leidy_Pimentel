# %% [markdown]
# <a href="https://colab.research.google.com/github/Leima20/Sprint7_Leidy_Pimentel/blob/main/sprint_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Nivell 1***
#
# **Exercici 1: Selecció de Personal**
# Tu treballes com a analista de dades en el departament de RRHH d'una empresa. S'ha obert una nova oferta laboral interna i l'empresa ha decidit que només les primeres 10 persones que s'inscriguin podran participar en el procés de selecció.
# Per això, t'han encarregat desenvolupar una eina senzilla en Python que actuï com a formulari d'inscripció i sistema de classificació inicial. Aquest formulari ha de permetre introduir, per a cada candidat/a:
#
# Nom i Cognoms
# Telèfon de contacte
# Anys d'experiència dins de l'empresa
# Coneixement de Català (0–3 punts)
# 0 = sense coneixement
# 1 = fins a nivell B1
# 2 = nivell B2
# 3 = C1 o superior
# Domini d'Excel (0–3 punts)
# 0 = nivell bàsic
# 1 = ús de funcions
# 2 = taules dinàmiques
# 3 = Visual Basic i Macros
# Títol acadèmic (0–3 punts)
# 0 = ESO
# 1 = FP
# 2 = Universitat
# 3 = Màster o superior
# Assegurant-se que tota la informació introduïda és correcta i entra dins els valors permesos. A partir d'aquestes dades, el programa haurà de calcular una puntuació total aplicant el pes de l'experiència (anys * 1.5) i sumant-hi els punts de català, excel i titulació, i a continuació classificar automàticament cada persona segons els llindars establerts per l'empresa:
#
# » Prioritat Alta → puntuació ≥ 12
# » Candidat adequat → 8 ≤ puntuació < 12
# » No prioritari → puntuació < 8
# Cada vegada que algú complet a el formulari, s'ha de mostrar la seva puntuació individual. Quan ja s'hagin inscrit exactament deu persones, l'eina ha de deixar d'acceptar nous registres i generar un informe final en pantalla, ordenat primer segons la prioritat i, en cas d'empat, per la puntuació obtinguda. Aquest informe ha d'incloure el nom, el telèfon i la puntuació de cada candidat per tal que el departament de RRHH els pugui contactar ràpidament.

# %% [markdown]
# **Objetivo: Crear un generador de contraseñas parametrizable que asegure aleatoriedad y cumplimiento de tipos de caracteres seleccionados.**

# %% [markdown]
# **Algoritmo General:**
#
#
# Sistema de Inscripción
# Configuración: Definición de límites y estructuras de datos.
#
# Entrada y Validación: Funciones modulares (solicitar_texto/número) para capturar datos con filtrado de errores.
#
# Lógica de Negocio: Cálculo de puntuación y clasificación de prioridad con pesos asignados.
#
# Orquestación:
#
# Manual: Bucle de control para registro interactivo de 10 candidatos.
#
# Pruebas: Motor de procesamiento automático para validación con datos predefinidos.
#
# Salida: Generación de informe tabular con ordenamiento doble (prioridad y puntuación).

# %% [markdown]
# **Desgranaje del Sistema Modular:**
#
#
# Cada función sigue el patrón de diseño funcional: Recibir -> Procesar -> Retornar.
#
# solicitar_texto / solicitar_numero:
# * Reciben el mensaje de prompt
# * Comprueban que la entrada sea válida (no vacía/formato numérico)
# * Retornan el valor validado.
#
# obtenir_dades:
# * Recibe el índice actual y y la lista de datos inputs.
# * Extrae los 6 elementos del candidato (nombre, teléfono, exp, cat, exc, tit). * Retorna la lista o tupla con los datos extraídos listos para procesar.
#
# calcular_puntuacion:
# * Recibe los valores numéricos extraídos.
# * Aplica la fórmula de ponderación definida. RETORNA el total acumulado.
#
# obtener_prioridad:
# * Recibe la puntuación total. COMPARA contra los umbrales de negocio establecidos. RETORNA una tupla con la categoría (string) y el peso numérico (float) para facilitar el ordenamiento.
#
# generar_informe:
# * Recibe la lista de diccionarios con los candidatos procesados.
# * Aplica el algoritmo de ordenamiento doble (primero por peso de prioridad y luego por puntuación).
# * Imprime el reporte estructurado en formato de tabla.

# %% [markdown]
# obtenir_dades(i, inputs)
# Recibir el índice actual i y la lista de inputs completa.
#
# Extraer los 6 elementos correspondientes al candidato.
#
# Retornar la lista con los datos extraídos.

# %% [markdown]
# **1-Funciones de Entrada y Validación**
#
# *solicitar_texto(mensaje)*
# * Inicia un bucle infinito para garantizar la entrada.
# * Solicita la entrada por teclado y elimina espacios innecesarios.
# * Valida si el campo tiene contenido; si es así, lo retorna.
# * Si está vacío, muestra un error y repite.

# %%
def solicitar_texto(mensaje):
    while True:
        valor = input(mensaje).strip()
        if valor: return valor
        print("Error: El campo no puede estar vacío.")

# %% [markdown]
# **solicitar_numero(mensaje)**
# * Solicita la entrada por teclado.
# * Intenta convertir la entrada a un número entero.
# * Si tiene éxito, lo retorna.
# * Si falla (ValueError), retorna -1 como código de error.

# %%
def solicitar_numero(mensaje):
    valor = input(mensaje).strip()
    try:
        return int(valor)
    except ValueError:
        return -1

# %% [markdown]
# 2. Lógica de Negocio y Clasificacióncalcular_puntuacion(experiencia, catalan, excel, titulacion)Verifica si los valores numéricos están fuera del rango permitido (0-3 para competencias, >=0 para experiencia).Si hay error, retorna -1.0.Si son válidos, aplica la ponderación: $(exp * 1.5) + cat + exc + tit$.Retorna el resultado final.

# %%
def calcular_puntuacion(experiencia, catalan, excel, titulacion):
    if (catalan < 0 or catalan > 3 or
        excel < 0 or excel > 3 or
        titulacion < 0 or titulacion > 3 or
        experiencia < 0):
        return -1.0
    return (experiencia * 1.5) + catalan + excel + titulacion

# %% [markdown]
# obtener_prioridad(puntuacion)
# Si la puntuación es -1.0, retorna un error y peso 0.
#
# Evalúa los rangos (>=12, >=8) para asignar la categoría.
#
# Retorna la etiqueta textual y un valor numérico para facilitar el ordenamiento.

# %%
def obtener_prioridad(puntuacion):
    if puntuacion == -1.0: return "ERROR: Datos Inválidos", 0
    if puntuacion >= 12: return "Prioridad Alta", 3
    if puntuacion >= 8: return "Candidato adecuado", 2
    return "No prioritario", 1

# %% [markdown]
# 3-Salida y Orquestación
# generar_informe(candidatos)
# Ordena la lista de candidatos utilizando los campos de prioridad y puntuación de forma descendente.
#
# Prepara el formato visual de tabla.
#
# Recorre la lista y muestra cada candidato formateado.

# %%
def generar_informe(candidatos):
    print("\n" + "="*75)
    print("INFORME FINAL DE SELECCIÓN - DEPARTAMENTO DE RRHH")
    print("="*75)
    candidatos_ordenados = sorted(candidatos, key=lambda x: (x['peso_prioridad'], x['puntuacion']), reverse=True)
    for c in candidatos_ordenados:
        puntos_mostrar = "N/A" if c['puntuacion'] == -1.0 else c['puntuacion']
        print(f"{c['prioridad']:<20} | {c['nombre']:<15} | Puntos: {puntos_mostrar}")

# %% [markdown]
# ejecutar_sistema_inscripcion_manual()
# Inicializa la lista de candidatos.
#
# Entra en un bucle mientras el número de inscritos sea menor a 10.
#
# Solicita datos, calcula puntuación y guarda en un diccionario.
#
# Finaliza llamando a generar_informe.

# %%
def ejecutar_sistema_inscripcion_manual():
    lista_candidatos = []
    while len(lista_candidatos) < 10:
        nombre = solicitar_texto("Nombre y Apellidos: ")
        telefono = solicitar_texto("Teléfono: ")
        exp = solicitar_numero("Años de experiencia: ")
        cat = solicitar_numero("Nivel Catalán (0-3): ")
        exc = solicitar_numero("Nivel Excel (0-3): ")
        tit = solicitar_numero("Título académico (0-3): ")

        puntos = calcular_puntuacion(exp, cat, exc, tit)
        etiqueta, peso = obtener_prioridad(puntos)

        lista_candidatos.append({
            'nombre': nombre, 'telefono': telefono, 'puntuacion': puntos,
            'prioridad': etiqueta, 'peso_prioridad': peso
        })
    generar_informe(lista_candidatos)

# %%
def procesar_lista_test(lista_inputs):
    lista_candidatos = []
    # Usamos saltos de 6 en 6 (los 6 datos de cada candidato)
    for i in range(0, len(lista_inputs), 6):
        if len(lista_candidatos) >= 10: break # Límite de 10

        # Extraer datos de la lista de prueba
        nombre = lista_inputs[i]
        telefono = lista_inputs[i+1]
        exp = lista_inputs[i+2]
        cat = lista_inputs[i+3]
        exc = lista_inputs[i+4]
        tit = lista_inputs[i+5]

        # Calcular y guardar
        puntos = calcular_puntuacion(exp, cat, exc, tit)
        etiqueta, peso = obtener_prioridad(puntos)

        # Solo añadimos si los datos son válidos
        if puntos != -1.0:
            lista_candidatos.append({
                'nombre': nombre, 'telefono': telefono, 'puntuacion': puntos,
                'prioridad': etiqueta, 'peso_prioridad': peso
            })

    # Generar el informe final
    generar_informe(lista_candidatos)

# Ejecuta esto para ver los resultados con los datos de prueba
inputs_test = [
    "Laura Serra", "608112233", 6, 3, 3, 3,
    "Clara Gómez", "655221199", 3, 3, 3, 2,
    "Sergio López", "644112211", 3, 2, 2, 2,
    "Candidat Error", "611000000", 5, 7, 3, 2,
    "Marta Ruiz", "699887766", 2, 3, 2, 1,
    "Marc Vidal", "612443322", 6, 3, 3, 3,
    "Júlia Romero", "677998877", 5, 3, 3, 2,
    "Pol Navarro", "699554433", 4, 3, 2, 2,
    "David Ferrer", "677665544", 2, 1, 1, 1,
    "Anna Paredes", "633221144", 1, 2, 1, 0,
    "Anibal Paredes", "644272727", 1, 2, 1, 0,
    "Núria Casals", "600112200", 8, 2, 3, 3
]

procesar_lista_test(inputs_test)
# Out:
# ...
# INFORME FINAL DE SELECCIÓN - DEPARTAMENTO DE RRHH
# ...
# Prioridad Alta       | Laura Serra     | Puntos: 18.0
# Prioridad Alta       | Marc Vidal      | Puntos: 18.0
# Prioridad Alta       | Júlia Romero    | Puntos: 15.5
# Prioridad Alta       | Pol Navarro     | Puntos: 13.0
# Prioridad Alta       | Clara Gómez     | Puntos: 12.5
# Candidato adecuado   | Sergio López    | Puntos: 10.5
# Candidato adecuado   | Marta Ruiz      | Puntos: 9.0
# No prioritario       | David Ferrer    | Puntos: 6.0
# No prioritario       | Anna Paredes    | Puntos: 4.5
# No prioritario       | Anibal Paredes  | Puntos: 4.5
